# %% [markdown]
# ## ================================ PT. 3 ================================
# #  >>>>>>>>>>>>>>>>>>>> MACHINE LEARNING <<<<<<<<<<<<<<<<<<<<
# ## =====================================================================

# %%
import numpy as np
import geopandas as gpd
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# # Regression
# ###  –––––––––––––––

# %%
BusMRTGeoData = pd.read_csv('BusMRTGeoDataSubzone.csv')
BusMRTGeoData
# Out:
#           SUBZONE_N  BUS_TAP_IN_TAP_OUT_VOLUME_WEEKDAY_PEAK  \
# 0          ALJUNIED                                272101.0
# 1        ANAK BUKIT                                 78683.0
# 2        ANCHORVALE                                 80421.0
# 3       BEDOK NORTH                                514937.0
# 4   BEDOK RESERVOIR                                107940.0
# ..              ...                                     ...
# 81   WOODLANDS EAST                                283127.0
# 82   WOODLANDS WEST                                129634.0
# 83          YEW TEE                                107981.0
# 84     YIO CHU KANG                                114012.0
# 85      YISHUN WEST                                251923.0
#
#     BUS_TAP_IN_TAP_OUT_VOLUME_PEAK  BUS_TAP_IN_TAP_OUT_VOLUME_WEEKDAY  \
# 0                        1524723.0                          1602735.0
# 1                         435307.0                           478669.0
# 2                         443213.0                           542681.0
# 3                        2876278.0                          3408440.0
# 4                         598335.0                           651821.0
# ..                             ...                                ...
# 81                       1552276.0                          1710348.0
# 82                        719971.0                           850840.0
# 83                        598776.0                           708942.0
# 84                        604035.0                           549487.0
# 85                       1406888.0                          1609608.0
#
#     BUS_TAP_IN_TAP_OUT_VOLUME_WEEKLY  BUS_PEAK_HOUR_PERCENTAGE (%)  \
# 0                          9329329.0                     16.343330
# 1                          2742579.0                     15.872177
# 2                          3076215.0                     14.407738
# 3                         19588547.0                     14.683468
# 4                          3731588.0                     16.034326
# ..                               ...                           ...
# 81                         9687117.0                     16.024128
# 82                         4838125.0                     14.881199
# 83                         4064449.0                     14.732034
# 84                         3002239.0                     20.119484
# 85                         9260108.0                     15.192998
#
#     BUS_WEEKDAY_PERCENTAGE (%)  MRT_TAP_IN_TAP_OUT_VOLUME_WEEKDAY_PEAK  \
# 0                    85.897657                                205135.0
# 1                    87.266219                                 68900.0
# 2                    88.205961                                 42201.0
# 3                    87.000838                                185128.0
# 4                    87.338286                                 47536.0
# ..                         ...                                     ...
# 81                   88.279516                                289600.0
# 82                   87.930758                                125307.0
# 83                   87.212559                                194970.0
# 84                   91.512868                                174329.0
# 85                   86.910865                                318412.0
#
#     MRT_TAP_IN_TAP_OUT_VOLUME_PEAK  MRT_TAP_IN_TAP_OUT_VOLUME_WEEKDAY  ...  \
# 0                        1125054.0                          1067636.0  ...
# 1                         383243.0                           371088.0  ...
# 2                         231522.0                           269032.0  ...
# 3                        1020027.0                          1017300.0  ...
# 4                         256282.0                           226403.0  ...
# ..                             ...                                ...  ...
# 81                       1574654.0                          1579028.0  ...
# 82                        689116.0                           728756.0  ...
# 83                       1054779.0                          1037986.0  ...
# 84                        916778.0                           815902.0  ...
# 85                       1741819.0                          1775142.0  ...
#
#     TAP_IN_TAP_OUT_VOLUME_WEEKDAY  TAP_IN_TAP_OUT_VOLUME_WEEKLY  \
# 0                       2670371.0                    15454280.0
# 1                        849757.0                     4909818.0
# 2                        811713.0                     4596871.0
# 3                       4425740.0                    25472206.0
# 4                        878224.0                     5012083.0
# ..                            ...                           ...
# 81                      3289376.0                    18614145.0
# 82                      1579596.0                     8975706.0
# 83                      1746928.0                     9926964.0
# 84                      1365389.0                     7430472.0
# 85                      3384750.0                    19424600.0
#
#     PEAK_HOUR_PERCENTAGE (%)  WEEKDAY_PERCENTAGE (%)  \
# 0                  17.145910               86.395840
# 1                  16.671697               86.536507
# 2                  14.678136               88.289730
# 3                  15.296300               86.873905
# 4                  17.051134               87.610680
# ..                       ...                     ...
# 81                 16.798676               88.356892
# 82                 15.698899               87.992855
# 83                 16.657208               87.989037
# 84                 20.467246               91.877676
# 85                 16.209894               87.125346
#
#     ('2020', 'Male Percentage')  ('2020', '00 - 19')  ('2020', '20 - 39')  \
# 0                      0.493623                 6150                10720
# 1                      0.474166                 4280                 5660
# 2                      0.492519                13550                14460
# 3                      0.485093                13230                20760
# 4                      0.489988                 5280                 6820
# ..                          ...                  ...                  ...
# 81                     0.499949                23130                30470
# 82                     0.508994                 6220                10300
# 83                     0.497771                 8460                11480
# 84                          NaN                    0                    0
# 85                     0.495641                 9000                14410
#
#     ('2020', '40 - 59')  ('2020', '60 & Over')  ('2020', 'Average Income')
# 0                 12170                  10940                11730.102220
# 1                  6190                   5750                19739.484317
# 2                 13710                   6410                10559.805071
# 3                 24610                  23260                 8815.353975
# 4                  7960                   5420                12406.950807
# ..                  ...                    ...                         ...
# 81                31480                  13910                 9709.300993
# 82                 9840                   7560                 7374.195426
# 83                13730                   6730                11017.340267
# 84                    0                      0                         NaN
# 85                17210                  13280                 8709.092919
#
# [86 rows x 25 columns]

# %%
BusMRTGeoData_reg = BusMRTGeoData.filter(['SUBZONE_N', 'TAP_IN_TAP_OUT_VOLUME_WEEKLY', 'PEAK_HOUR_PERCENTAGE (%)', 'WEEKDAY_PERCENTAGE (%)', "('2020', 'Male Percentage')", "('2020', '00 - 19')", "('2020', '20 - 39')", "('2020', '40 - 59')", "('2020', '60 & Over')", "('2020', 'Average Income')"], axis = 1)
BusMRTGeoData_reg['PEAK_HOUR_PERCENTAGE (%)'] = BusMRTGeoData_reg['PEAK_HOUR_PERCENTAGE (%)']/100
BusMRTGeoData_reg['WEEKDAY_PERCENTAGE (%)'] = BusMRTGeoData_reg['WEEKDAY_PERCENTAGE (%)']/100
BusMRTGeoData_reg = BusMRTGeoData_reg.rename(columns={'PEAK_HOUR_PERCENTAGE (%)': 'Peak Hour Percentage'})
BusMRTGeoData_reg = BusMRTGeoData_reg.rename(columns={"WEEKDAY_PERCENTAGE (%)": 'Weekday Percentage'})
BusMRTGeoData_reg = BusMRTGeoData_reg.rename(columns={"('2020', 'Male Percentage')": 'Male Percentage'})
BusMRTGeoData_reg = BusMRTGeoData_reg.rename(columns={"('2020', '00 - 19')": '00 - 19'})
BusMRTGeoData_reg = BusMRTGeoData_reg.rename(columns={"('2020', '20 - 39')": '20 - 39'})
BusMRTGeoData_reg = BusMRTGeoData_reg.rename(columns={"('2020', '40 - 59')": '40 - 59'})
BusMRTGeoData_reg = BusMRTGeoData_reg.rename(columns={"('2020', '60 & Over')": '60 & Over'})
BusMRTGeoData_reg = BusMRTGeoData_reg.rename(columns={"('2020', 'Average Income')": 'Average Income'})
BusMRTGeoData_reg['Male Percentage'] = BusMRTGeoData_reg['Male Percentage'].replace(np.nan, 0) #Replace '-' with '0'
BusMRTGeoData_reg['Average Income'] = BusMRTGeoData_reg['Average Income'].replace(np.nan, 0) #Replace '-' with '0'
BusMRTGeoData_reg
# Out:
#           SUBZONE_N  TAP_IN_TAP_OUT_VOLUME_WEEKLY  Peak Hour Percentage  \
# 0          ALJUNIED                    15454280.0              0.171459
# 1        ANAK BUKIT                     4909818.0              0.166717
# 2        ANCHORVALE                     4596871.0              0.146781
# 3       BEDOK NORTH                    25472206.0              0.152963
# 4   BEDOK RESERVOIR                     5012083.0              0.170511
# ..              ...                           ...                   ...
# 81   WOODLANDS EAST                    18614145.0              0.167987
# 82   WOODLANDS WEST                     8975706.0              0.156989
# 83          YEW TEE                     9926964.0              0.166572
# 84     YIO CHU KANG                     7430472.0              0.204672
# 85      YISHUN WEST                    19424600.0              0.162099
#
#     Weekday Percentage  Male Percentage  00 - 19  20 - 39  40 - 59  60 & Over  \
# 0             0.863958         0.493623     6150    10720    12170      10940
# 1             0.865365         0.474166     4280     5660     6190       5750
# 2             0.882897         0.492519    13550    14460    13710       6410
# 3             0.868739         0.485093    13230    20760    24610      23260
# 4             0.876107         0.489988     5280     6820     7960       5420
# ..                 ...              ...      ...      ...      ...        ...
# 81            0.883569         0.499949    23130    30470    31480      13910
# 82            0.879929         0.508994     6220    10300     9840       7560
# 83            0.879890         0.497771     8460    11480    13730       6730
# 84            0.918777         0.000000        0        0        0          0
# 85            0.871253         0.495641     9000    14410    17210      13280
#
#     Average Income
# 0     11730.102220
# 1     19739.484317
# 2     10559.805071
# 3      8815.353975
# 4     12406.950807
# ..             ...
# 81     9709.300993
# 82     7374.195426
# 83    11017.340267
# 84        0.000000
# 85     8709.092919
#
# [86 rows x 10 columns]

# %% [markdown]
# ## Univariate Linear Models

# %% [markdown]
# ### Variable 1: Predicting TAP_IN_TAP_OUT_VOLUME_WEEKLY using Peak Hour Percentage

# %%
sb.jointplot(data = BusMRTGeoData_reg, x = 'Peak Hour Percentage', y = 'TAP_IN_TAP_OUT_VOLUME_WEEKLY', height = 12)

# %%
BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'].corr(BusMRTGeoData_reg['Peak Hour Percentage'])
# Out:
# -0.2516931050720493

# %%
# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
y = pd.DataFrame(BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'])
X = pd.DataFrame(BusMRTGeoData_reg['Peak Hour Percentage'])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)
# Out:
# Train Set : (64, 1) (64, 1)
# Test Set  : (22, 1) (22, 1)

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
linreg = LinearRegression()

linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Visual Representation of the Linear Regression Model

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [19682820.86079232]
# Coefficients 	: a =  [[-71968414.48563427]]

# %%
# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
ev1 = linreg.score(X_train, y_train)
print("Explained Variance (R^2) \t:", ev1)

# Import the required metric from sklearn
from sklearn.metrics import mean_squared_error

# Predict the response on the train set
y_train_pred = linreg.predict(X_train)

# Compute MSE on the train set
mse1 = mean_squared_error(y_train, y_train_pred)
print("Mean Squared Error (MSE) \t:", mse1)
# Out:
# Explained Variance (R^2) 	: 0.06714677759214738
# Mean Squared Error (MSE) 	: 42717161256900.3

# %% [markdown]
# #### Prediction of Response based on the Predictor
#
# Predict `TAP_IN_TAP_OUT_VOLUME_WEEKLY` given `Peak Hour Percentage` in the Test dataset.

# %%
y_test_pred = linreg.predict(X_test)

# %%
# Plot the Predictions on a Scatterplot
f = plt.figure(figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
evTest1 = linreg.score(X_test, y_test)
print("Explained Variance (R^2) \t:", evTest1)
mseTest1 = mean_squared_error(y_test, y_test_pred)
print("Mean Squared Error (MSE) \t:", mseTest1)
# Out:
# Explained Variance (R^2) 	: 0.039681731860989444
# Mean Squared Error (MSE) 	: 22519622637624.734

# %% [markdown]
# ### Variable 2: Predicting TAP_IN_TAP_OUT_VOLUME_WEEKLY using Weekday Percentage

# %%
sb.jointplot(data = BusMRTGeoData_reg, x = 'Weekday Percentage', y = 'TAP_IN_TAP_OUT_VOLUME_WEEKLY', height = 12)

# %%
BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'].corr(BusMRTGeoData_reg['Weekday Percentage'])
# Out:
# -0.12952487449334363

# %%
# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
y = pd.DataFrame(BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'])
X = pd.DataFrame(BusMRTGeoData_reg['Weekday Percentage'])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)
# Out:
# Train Set : (64, 1) (64, 1)
# Test Set  : (22, 1) (22, 1)

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
linreg = LinearRegression()

linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Visual Representation of the Linear Regression Model

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [33887002.85998498]
# Coefficients 	: a =  [[-30904859.08968294]]

# %%
# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
ev2 = linreg.score(X_train, y_train)
print("Explained Variance (R^2) \t:", ev2)

# Import the required metric from sklearn
from sklearn.metrics import mean_squared_error

# Predict the response on the train set
y_train_pred = linreg.predict(X_train)

# Compute MSE on the train set
mse2 = mean_squared_error(y_train, y_train_pred)
print("Mean Squared Error (MSE) \t:", mse2)
# Out:
# Explained Variance (R^2) 	: 0.016370995552130396
# Mean Squared Error (MSE) 	: 35335496500481.266

# %% [markdown]
# #### Prediction of Response based on the Predictor
#
# Predict `TAP_IN_TAP_OUT_VOLUME_WEEKLY` given `Weekday Percentage` in the Test dataset.

# %%
y_test_pred = linreg.predict(X_test)

# %%
# Plot the Predictions on a Scatterplot
f = plt.figure(figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
evTest2 = linreg.score(X_test, y_test)
print("Explained Variance (R^2) \t:", evTest2)
mseTest2 = mean_squared_error(y_test, y_test_pred)
print("Mean Squared Error (MSE) \t:", mseTest2)
# Out:
# Explained Variance (R^2) 	: -0.004405371599638386
# Mean Squared Error (MSE) 	: 51548198770905.83

# %% [markdown]
# ### Variable 3: Predicting TAP_IN_TAP_OUT_VOLUME_WEEKLY using Male Percentage

# %%
sb.jointplot(data = BusMRTGeoData_reg, x = 'Male Percentage', y = 'TAP_IN_TAP_OUT_VOLUME_WEEKLY', height = 12)

# %%
BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'].corr(BusMRTGeoData_reg['Male Percentage'])
# Out:
# 0.24232609709596914

# %%
# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
y = pd.DataFrame(BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'])
X = pd.DataFrame(BusMRTGeoData_reg['Male Percentage'])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)
# Out:
# Train Set : (64, 1) (64, 1)
# Test Set  : (22, 1) (22, 1)

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
linreg = LinearRegression()

linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Visual Representation of the Linear Regression Model

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [2664796.51147897]
# Coefficients 	: a =  [[9491467.84988919]]

# %%
# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
ev3 = linreg.score(X_train, y_train)
print("Explained Variance (R^2) \t:", ev3)

# Import the required metric from sklearn
from sklearn.metrics import mean_squared_error

# Predict the response on the train set
y_train_pred = linreg.predict(X_train)

# Compute MSE on the train set
mse3 = mean_squared_error(y_train, y_train_pred)
print("Mean Squared Error (MSE) \t:", mse3)
# Out:
# Explained Variance (R^2) 	: 0.048214114102406946
# Mean Squared Error (MSE) 	: 36734404664885.74

# %% [markdown]
# #### Prediction of Response based on the Predictor
#
# Predict `TAP_IN_TAP_OUT_VOLUME_WEEKLY` given `Male Percentage` in the Test dataset.

# %%
y_test_pred = linreg.predict(X_test)

# %%
# Plot the Predictions on a Scatterplot
f = plt.figure(figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
evTest3 = linreg.score(X_test, y_test)
print("Explained Variance (R^2) \t:", evTest3)
mseTest3 = mean_squared_error(y_test, y_test_pred)
print("Mean Squared Error (MSE) \t:", mseTest3)
# Out:
# Explained Variance (R^2) 	: -0.21293289393562675
# Mean Squared Error (MSE) 	: 25982793678699.05

# %% [markdown]
# ### Variable 4: Predicting TAP_IN_TAP_OUT_VOLUME_WEEKLY using 00 - 19

# %%
sb.jointplot(data = BusMRTGeoData_reg, x = '00 - 19', y = 'TAP_IN_TAP_OUT_VOLUME_WEEKLY', height = 12)

# %%
BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'].corr(BusMRTGeoData_reg['00 - 19'])
# Out:
# 0.6164596239700507

# %%
# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
y = pd.DataFrame(BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'])
X = pd.DataFrame(BusMRTGeoData_reg['00 - 19'])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)
# Out:
# Train Set : (64, 1) (64, 1)
# Test Set  : (22, 1) (22, 1)

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
linreg = LinearRegression()

linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Visual Representation of the Linear Regression Model

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [3403987.71632981]
# Coefficients 	: a =  [[750.27647071]]

# %%
# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
ev4 = linreg.score(X_train, y_train)
print("Explained Variance (R^2) \t:", ev4)

# Import the required metric from sklearn
from sklearn.metrics import mean_squared_error

# Predict the response on the train set
y_train_pred = linreg.predict(X_train)

# Compute MSE on the train set
mse4 = mean_squared_error(y_train, y_train_pred)
print("Mean Squared Error (MSE) \t:", mse4)
# Out:
# Explained Variance (R^2) 	: 0.44700620418766046
# Mean Squared Error (MSE) 	: 24051206385210.305

# %% [markdown]
# #### Prediction of Response based on the Predictor
#
# Predict `TAP_IN_TAP_OUT_VOLUME_WEEKLY` given `00 - 19` in the Test dataset.

# %%
y_test_pred = linreg.predict(X_test)

# %%
# Plot the Predictions on a Scatterplot
f = plt.figure(figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
evTest4 = linreg.score(X_test, y_test)
print("Explained Variance (R^2) \t:", evTest4)
mseTest4 = mean_squared_error(y_test, y_test_pred)
print("Mean Squared Error (MSE) \t:", mseTest4)
# Out:
# Explained Variance (R^2) 	: 0.09345077506372912
# Mean Squared Error (MSE) 	: 27317156425120.2

# %% [markdown]
# ### Variable 5: Predicting AP_IN_TAP_OUT_VOLUME_WEEKLY using 20 - 39

# %%
sb.jointplot(data = BusMRTGeoData_reg, x = '20 - 39', y = 'TAP_IN_TAP_OUT_VOLUME_WEEKLY', height = 12)

# %%
BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'].corr(BusMRTGeoData_reg['20 - 39'])
# Out:
# 0.6952759625021925

# %%
# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
y = pd.DataFrame(BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'])
X = pd.DataFrame(BusMRTGeoData_reg['20 - 39'])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)
# Out:
# Train Set : (64, 1) (64, 1)
# Test Set  : (22, 1) (22, 1)

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
linreg = LinearRegression()

linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Visual Representation of the Linear Regression Model

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [3136392.90907835]
# Coefficients 	: a =  [[591.47472235]]

# %%
# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
ev5 = linreg.score(X_train, y_train)
print("Explained Variance (R^2) \t:", ev5)

# Import the required metric from sklearn
from sklearn.metrics import mean_squared_error

# Predict the response on the train set
y_train_pred = linreg.predict(X_train)

# Compute MSE on the train set
mse5 = mean_squared_error(y_train, y_train_pred)
print("Mean Squared Error (MSE) \t:", mse5)
# Out:
# Explained Variance (R^2) 	: 0.5422221783340766
# Mean Squared Error (MSE) 	: 16992577565800.861

# %% [markdown]
# #### Prediction of Response based on the Predictor
#
# Predict `TAP_IN_TAP_OUT_VOLUME_WEEKLY` given `20 - 39` in the Test dataset.

# %%
y_test_pred = linreg.predict(X_test)

# %%
# Plot the Predictions on a Scatterplot
f = plt.figure(figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
evTest5 = linreg.score(X_test, y_test)
print("Explained Variance (R^2) \t:", evTest5)
mseTest5 = mean_squared_error(y_test, y_test_pred)
print("Mean Squared Error (MSE) \t:", mseTest5)
# Out:
# Explained Variance (R^2) 	: 0.3350891292067484
# Mean Squared Error (MSE) 	: 31636501028075.465

# %% [markdown]
# ### Variable 6: Predicting TAP_IN_TAP_OUT_VOLUME_WEEKLY using 40 - 59

# %%
sb.jointplot(data = BusMRTGeoData_reg, x = '40 - 59', y = 'TAP_IN_TAP_OUT_VOLUME_WEEKLY', height = 12)

# %%
BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'].corr(BusMRTGeoData_reg['40 - 59'])
# Out:
# 0.7356997525223683

# %%
# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
y = pd.DataFrame(BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'])
X = pd.DataFrame(BusMRTGeoData_reg['40 - 59'])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)
# Out:
# Train Set : (64, 1) (64, 1)
# Test Set  : (22, 1) (22, 1)

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
linreg = LinearRegression()

linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Visual Representation of the Linear Regression Model

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [2407023.21252031]
# Coefficients 	: a =  [[678.24740835]]

# %%
# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
ev6 = linreg.score(X_train, y_train)
print("Explained Variance (R^2) \t:", ev6)

# Import the required metric from sklearn
from sklearn.metrics import mean_squared_error

# Predict the response on the train set
y_train_pred = linreg.predict(X_train)

# Compute MSE on the train set
mse6 = mean_squared_error(y_train, y_train_pred)
print("Mean Squared Error (MSE) \t:", mse6)
# Out:
# Explained Variance (R^2) 	: 0.5873223832454292
# Mean Squared Error (MSE) 	: 16856433895108.129

# %% [markdown]
# #### Prediction of Response based on the Predictor
#
# Predict `TAP_IN_TAP_OUT_VOLUME_WEEKLY` given `40 - 59` in the Test dataset.

# %%
y_test_pred = linreg.predict(X_test)

# %%
# Plot the Predictions on a Scatterplot
f = plt.figure(figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
evTest6 = linreg.score(X_test, y_test)
print("Explained Variance (R^2) \t:", evTest6)
mseTest6 = mean_squared_error(y_test, y_test_pred)
print("Mean Squared Error (MSE) \t:", mseTest6)
# Out:
# Explained Variance (R^2) 	: 0.37965713690033565
# Mean Squared Error (MSE) 	: 23409476063930.12

# %% [markdown]
# ### Variable 7: Predicting TAP_IN_TAP_OUT_VOLUME_WEEKLY using 60 & Over

# %%
sb.jointplot(data = BusMRTGeoData_reg, x = '60 & Over', y = 'TAP_IN_TAP_OUT_VOLUME_WEEKLY', height = 12)

# %%
BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'].corr(BusMRTGeoData_reg['60 & Over'])
# Out:
# 0.7503595742097162

# %%
# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
y = pd.DataFrame(BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'])
X = pd.DataFrame(BusMRTGeoData_reg['60 & Over'])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)
# Out:
# Train Set : (64, 1) (64, 1)
# Test Set  : (22, 1) (22, 1)

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
linreg = LinearRegression()

linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Visual Representation of the Linear Regression Model

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [3040921.57048516]
# Coefficients 	: a =  [[817.63171218]]

# %%
# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
ev7 = linreg.score(X_train, y_train)
print("Explained Variance (R^2) \t:", ev7)

# Import the required metric from sklearn
from sklearn.metrics import mean_squared_error

# Predict the response on the train set
y_train_pred = linreg.predict(X_train)

# Compute MSE on the train set
mse7 = mean_squared_error(y_train, y_train_pred)
print("Mean Squared Error (MSE) \t:", mse7)
# Out:
# Explained Variance (R^2) 	: 0.6091440104607524
# Mean Squared Error (MSE) 	: 14613740412616.453

# %% [markdown]
# #### Prediction of Response based on the Predictor
#
# Predict `TAP_IN_TAP_OUT_VOLUME_WEEKLY` given `60 & Over` in the Test dataset.

# %%
y_test_pred = linreg.predict(X_test)

# %%
# Plot the Predictions on a Scatterplot
f = plt.figure(figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
evTest7 = linreg.score(X_test, y_test)
print("Explained Variance (R^2) \t:", evTest7)
mseTest7 = mean_squared_error(y_test, y_test_pred)
print("Mean Squared Error (MSE) \t:", mseTest7)
# Out:
# Explained Variance (R^2) 	: 0.4486736458091949
# Mean Squared Error (MSE) 	: 26387096207648.83

# %% [markdown]
# ### Variable 8: Predicting TAP_IN_TAP_OUT_VOLUME_WEEKLY using Average Income

# %%
sb.jointplot(data = BusMRTGeoData_reg, x = 'Average Income', y = 'TAP_IN_TAP_OUT_VOLUME_WEEKLY', height = 12)

# %%
BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'].corr(BusMRTGeoData_reg['Average Income'])
# Out:
# -0.11799461908286209

# %%
# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
y = pd.DataFrame(BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'])
X = pd.DataFrame(BusMRTGeoData_reg['Average Income'])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)
# Out:
# Train Set : (64, 1) (64, 1)
# Test Set  : (22, 1) (22, 1)

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression object
linreg = LinearRegression()

linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Visual Representation of the Linear Regression Model

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [8233185.50046826]
# Coefficients 	: a =  [[-97.8592603]]

# %%
# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
ev8 = linreg.score(X_train, y_train)
print("Explained Variance (R^2) \t:", ev8)

# Import the required metric from sklearn
from sklearn.metrics import mean_squared_error

# Predict the response on the train set
y_train_pred = linreg.predict(X_train)

# Compute MSE on the train set
mse8 = mean_squared_error(y_train, y_train_pred)
print("Mean Squared Error (MSE) \t:", mse8)
# Out:
# Explained Variance (R^2) 	: 0.010330031397447703
# Mean Squared Error (MSE) 	: 48257605005950.055

# %% [markdown]
# #### Prediction of Response based on the Predictor
#
# Predict `TAP_IN_TAP_OUT_VOLUME_WEEKLY` given `Average Income` in the Test dataset.

# %%
y_test_pred = linreg.predict(X_test)

# %%
# Plot the Predictions on a Scatterplot
f = plt.figure(figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
# Explained Variance in simply the "Score"
evTest8 = linreg.score(X_test, y_test)
print("Explained Variance (R^2) \t:", evTest8)
mseTest8 = mean_squared_error(y_test, y_test_pred)
print("Mean Squared Error (MSE) \t:", mseTest8)
# Out:
# Explained Variance (R^2) 	: 0.020004908712024982
# Mean Squared Error (MSE) 	: 14177152902083.076

# %% [markdown]
# ### Comparing the Uni-Variate Linear Models

# %%
variables = ['Peak Hour Percentage', 'Weekday Percentage', 'Male Percentage', '00 - 19', '20 - 39', '40 - 59', '60 & Over', 'Average Income']
ev = [ev1, ev2, ev3, ev4, ev5, ev6, ev7, ev8]
mse = [mse1, mse2, mse3, mse4, mse5, mse6, mse7, mse8]
evTest = [evTest1, evTest2, evTest3, evTest4, evTest5, evTest6, evTest7, evTest8]
mseTest = [mseTest1, mseTest2, mseTest3, mseTest4, mseTest5, mseTest6, mseTest7, mseTest8]

for i in range(8):
    print(variables[i], ": Explained variance(train):", ev[i], "Mean Squared Error(train):", mse[i], "\nExplained variance(test):", evTest[i], "Mean Squared Error(test):", mseTest[i])
    print("\n")
# Out:
# Peak Hour Percentage : Explained variance(train): 0.06714677759214738 Mean Squared Error(train): 42717161256900.3
# Explained variance(test): 0.039681731860989444 Mean Squared Error(test): 22519622637624.734
#
#
# Weekday Percentage : Explained variance(train): 0.016370995552130396 Mean Squared Error(train): 35335496500481.266
# Explained variance(test): -0.004405371599638386 Mean Squared Error(test): 51548198770905.83
#
#
# Male Percentage : Explained variance(train): 0.048214114102406946 Mean Squared Error(train): 36734404664885.74
# Explained variance(test): -0.21293289393562675 Mean Squared Error(test): 25982793678699.05
#
#
# 00 - 19 : Explained variance(train): 0.44700620418766046 Mean Squared Error(train): 24051206385210.305
# Explained variance(test): 0.09345077506372912 Mean Squared Error(test): 27317156425120.2
#
#
# 20 - 39 : Explained variance(train): 0.5422221783340766 Mean Squared Error(train): 16992577565800.861
# Explained variance(test): 0.3350891292067484 Mean Squared Error(test): 31636501028075.465
#
#
# 40 - 59 : Explained variance(train): 0.5873223832454292 Mean Squared Error(train): 16856433895108.129
# Explained variance(test): 0.37965713690033565 Mean Squared Error(test): 23409476063930.12
#
#
# 60 & Over : Explained variance(train): 0.6091440104607524 Mean Squared Error(train): 14613740412616.453
# Explained variance(test): 0.4486736458091949 Mean Squared Error(test): 26387096207648.83
#
#
# Average Income : Explained variance(train): 0.010330031397447703 Mean Squared Error(train): 48257605005950.055
# Explained variance(test): 0.020004908712024982 Mean Squared Error(test): 14177152902083.076

# %% [markdown]
# * `TAP_IN_TAP_OUT_VOLUME_WEEKLY` vs `60 & Over` has the best Explained Variance (R^2) and minimum MSE on both the Train and Test Setsout of the models.
# * 6 variables to be used in the regression models would be `Peak Hour Percentage`, `00 - 19`, `20 - 39`, `40 - 59`, `60 & Over`, `Average Income`

# %% [markdown]
# ## Multivariate Models

# %% [markdown]
# ### Multivariate Linear Regression

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
y = pd.DataFrame(BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'])
X = pd.DataFrame(BusMRTGeoData_reg[['Peak Hour Percentage', '00 - 19', '20 - 39', '40 - 59', '60 & Over', 'Average Income']])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)

# Create a Linear Regression object
linreg = LinearRegression()

# Train the Linear Regression model
linreg.fit(X_train, y_train)
# Out:
# Train Set : (64, 5) (64, 1)
# Test Set  : (22, 5) (22, 1)
# LinearRegression()

# %% [markdown]
# #### Coefficients of the Linear Regression Model

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [9476911.70330757]
# Coefficients 	: a =  [[-3.33923741e+07 -2.08728692e+03  5.05514627e+02  1.87042637e+03
#   -4.61678782e+02]]

# %% [markdown]
# #### Prediction of Response based on the Predictor

# %%
# Predict values corresponding to Predictors
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Linear Regression Model

# %%
from sklearn.metrics import r2_score
print("Explained Variance (R^2) on Train Set \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) on Train Set \t:", mean_squared_error(y_train, y_train_pred))
print("Explained Variance (R^2) on Test Set \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) on Test Set \t:", mean_squared_error(y_test, y_test_pred))
# Out:
# Explained Variance (R^2) on Train Set 	: 0.6563020116794732
# Mean Squared Error (MSE) on Train Set 	: 16523202548213.326
# Explained Variance (R^2) on Test Set 	: 0.3278182343018037
# Mean Squared Error (MSE) on Test Set 	: 8515392013692.788

# %% [markdown]
# ### Decision Tree Regression

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
y = pd.DataFrame(BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'])
X = pd.DataFrame(BusMRTGeoData_reg[['Peak Hour Percentage', '00 - 19', '20 - 39', '40 - 59', '60 & Over', 'Average Income']])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_train_pred = regressor.predict(X_train)
y_test_pred = regressor.predict(X_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Decision Tree Regression Model

# %%
from sklearn.metrics import r2_score
print("Explained Variance (R^2) on Train Set \t:", regressor.score(X_train, y_train))
print("Mean Squared Error (MSE) on Train Set \t:", mean_squared_error(y_train, y_train_pred))
print("Explained Variance (R^2) on Test Set \t:", regressor.score(X_test, y_test))
print("Mean Squared Error (MSE) on Test Set \t:", mean_squared_error(y_test, y_test_pred))
# Out:
# Explained Variance (R^2) on Train Set 	: 1.0
# Mean Squared Error (MSE) on Train Set 	: 0.0
# Explained Variance (R^2) on Test Set 	: 0.38530454667224756
# Mean Squared Error (MSE) on Test Set 	: 35323430846434.95

# %% [markdown]
# ### Random Forest Regression

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression

# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
y = pd.DataFrame(BusMRTGeoData_reg['TAP_IN_TAP_OUT_VOLUME_WEEKLY'])
X = pd.DataFrame(BusMRTGeoData_reg[['Peak Hour Percentage', '00 - 19', '20 - 39', '40 - 59', '60 & Over', 'Average Income']])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

from sklearn.ensemble import RandomForestRegressor
regress = RandomForestRegressor()
regress.fit(X_train, y_train)
# Out:
# <ipython-input-471-616e5b1aed25>:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regress.fit(X_train, y_train)
# RandomForestRegressor()

# %%
y_train_pred = regress.predict(X_train)
y_test_pred = regress.predict(X_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %% [markdown]
# #### Goodness of Fit of the Random Forest Regression Model

# %%
from sklearn.metrics import r2_score
print("Explained Variance (R^2) on Train Set \t:", regress.score(X_train, y_train))
print("Mean Squared Error (MSE) on Train Set \t:", mean_squared_error(y_train, y_train_pred))
print("Explained Variance (R^2) on Test Set \t:", regress.score(X_test, y_test))
print("Mean Squared Error (MSE) on Test Set \t:", mean_squared_error(y_test, y_test_pred))
# Out:
# Explained Variance (R^2) on Train Set 	: 0.9090693068420266
# Mean Squared Error (MSE) on Train Set 	: 2631956419683.082
# Explained Variance (R^2) on Test Set 	: 0.5204403729707516
# Mean Squared Error (MSE) on Test Set 	: 33492258510203.516

# %% [markdown]
# * Random Forest Regression Model has the best Explained Variance (R^2) and minimum MSE on both the Train and Test Setsout of the models.
# * Therefore Random Forest Regression will be used to predict `TAP_IN_TAP_OUT_VOLUME_WEEKLY` in 2025

# %% [markdown]
# ## Feed 2025 Predictions Into Random Forest Regression Model

# %% [markdown]
# #### Feed demographic predictions in 2025 into the regression model, then find 20 subzones with the most tap ins and tap out (most traffic/demand for public transportation), hence these subzones will be most in need of MRT/Bus Stops

# %%
dT_predicted_subzone_data = pd.read_csv('dT_predicted_subzone_data.csv')
dT_predicted_subzone_data
# Out:
#     Male Percentage       00 - 19       20 - 39       40 - 59     60 & Over  \
# 0          0.492461   5122.252793  10458.081465  11223.163288  12593.503017
# 1          0.470599   4067.156260   5603.213452   5317.299340   7042.132011
# 2          0.491532  17236.756103  14465.103663  19500.791783  11801.692781
# 3          0.480100  10976.204112  18958.853121  22056.100938  27943.153446
# 4          0.496267   4860.626994   7077.883636   7833.619187   6448.624985
# ..              ...           ...           ...           ...           ...
# 70         0.494843  20729.174355  19196.080855  32524.779177   7367.837088
# 71         0.497475  21820.835205  29345.543639  32416.392273  23409.661388
# 72         0.503989   6106.183179   9709.618690   9311.253662  10994.809353
# 73         0.497592   4707.983975  10597.570993  11633.502435  10049.571598
# 74         0.493207   5586.482555  11041.790833  15295.013378  16387.116590
#
#     Average Income        SUBZONE_N
# 0     13975.923484         ALJUNIED
# 1     19689.614782       ANAK BUKIT
# 2     10323.206492       ANCHORVALE
# 3      8936.342609      BEDOK NORTH
# 4     12714.717735  BEDOK RESERVOIR
# ..             ...              ...
# 70    10233.068491    WATERWAY EAST
# 71     9628.062327   WOODLANDS EAST
# 72     7373.988048   WOODLANDS WEST
# 73    11200.734758          YEW TEE
# 74     9103.165953      YISHUN WEST
#
# [75 rows x 7 columns]

# %%
peak_Hour_Percentage = BusMRTGeoData_reg.filter(['SUBZONE_N', 'Peak Hour Percentage'])
peak_Hour_Percentage
# Out:
#           SUBZONE_N  Peak Hour Percentage
# 0          ALJUNIED              0.171459
# 1        ANAK BUKIT              0.166717
# 2        ANCHORVALE              0.146781
# 3       BEDOK NORTH              0.152963
# 4   BEDOK RESERVOIR              0.170511
# ..              ...                   ...
# 81   WOODLANDS EAST              0.167987
# 82   WOODLANDS WEST              0.156989
# 83          YEW TEE              0.166572
# 84     YIO CHU KANG              0.204672
# 85      YISHUN WEST              0.162099
#
# [86 rows x 2 columns]

# %%
dT_predicted_subzone_data = dT_predicted_subzone_data.filter(['Peak Hour Percentage', '00 - 19', '20 - 39', '40 - 59', '60 & Over','SUBZONE_N', 'Average Income'])
dT_predicted_subzone_data = pd.merge(peak_Hour_Percentage, dT_predicted_subzone_data, how='inner', on='SUBZONE_N') 
dT_predicted_subzone_data
# Out:
#           SUBZONE_N  Peak Hour Percentage       00 - 19       20 - 39  \
# 0          ALJUNIED              0.171459   5122.252793  10458.081465
# 1        ANAK BUKIT              0.166717   4067.156260   5603.213452
# 2        ANCHORVALE              0.146781  17236.756103  14465.103663
# 3       BEDOK NORTH              0.152963  10976.204112  18958.853121
# 4   BEDOK RESERVOIR              0.170511   4860.626994   7077.883636
# ..              ...                   ...           ...           ...
# 70    WATERWAY EAST              0.148130  20729.174355  19196.080855
# 71   WOODLANDS EAST              0.167987  21820.835205  29345.543639
# 72   WOODLANDS WEST              0.156989   6106.183179   9709.618690
# 73          YEW TEE              0.166572   4707.983975  10597.570993
# 74      YISHUN WEST              0.162099   5586.482555  11041.790833
#
#          40 - 59     60 & Over  Average Income
# 0   11223.163288  12593.503017    13975.923484
# 1    5317.299340   7042.132011    19689.614782
# 2   19500.791783  11801.692781    10323.206492
# 3   22056.100938  27943.153446     8936.342609
# 4    7833.619187   6448.624985    12714.717735
# ..           ...           ...             ...
# 70  32524.779177   7367.837088    10233.068491
# 71  32416.392273  23409.661388     9628.062327
# 72   9311.253662  10994.809353     7373.988048
# 73  11633.502435  10049.571598    11200.734758
# 74  15295.013378  16387.116590     9103.165953
#
# [75 rows x 7 columns]

# %%
pd.DataFrame(dT_predicted_subzone_data[['Peak Hour Percentage', '00 - 19', '20 - 39', '40 - 59', '60 & Over', 'Average Income']])
# Out:
#     Peak Hour Percentage       00 - 19       20 - 39       40 - 59  \
# 0               0.171459   5122.252793  10458.081465  11223.163288
# 1               0.166717   4067.156260   5603.213452   5317.299340
# 2               0.146781  17236.756103  14465.103663  19500.791783
# 3               0.152963  10976.204112  18958.853121  22056.100938
# 4               0.170511   4860.626994   7077.883636   7833.619187
# ..                   ...           ...           ...           ...
# 70              0.148130  20729.174355  19196.080855  32524.779177
# 71              0.167987  21820.835205  29345.543639  32416.392273
# 72              0.156989   6106.183179   9709.618690   9311.253662
# 73              0.166572   4707.983975  10597.570993  11633.502435
# 74              0.162099   5586.482555  11041.790833  15295.013378
#
#        60 & Over  Average Income
# 0   12593.503017    13975.923484
# 1    7042.132011    19689.614782
# 2   11801.692781    10323.206492
# 3   27943.153446     8936.342609
# 4    6448.624985    12714.717735
# ..           ...             ...
# 70   7367.837088    10233.068491
# 71  23409.661388     9628.062327
# 72  10994.809353     7373.988048
# 73  10049.571598    11200.734758
# 74  16387.116590     9103.165953
#
# [75 rows x 6 columns]

# %%
pred_2025 = pd.DataFrame(regress.predict(pd.DataFrame(dT_predicted_subzone_data[['Peak Hour Percentage', '00 - 19', '20 - 39', '40 - 59', '60 & Over', 'Average Income']])))
dT_predicted_subzone_data.insert(1, 'TAP_IN_TAP_OUT_VOLUME_WEEKLY_2025', pred_2025, True)
dT_predicted_subzone_data
# Out:
#           SUBZONE_N  TAP_IN_TAP_OUT_VOLUME_WEEKLY_2025  Peak Hour Percentage  \
# 0          ALJUNIED                         8991926.75              0.171459
# 1        ANAK BUKIT                         5967774.99              0.166717
# 2        ANCHORVALE                         9671322.12              0.146781
# 3       BEDOK NORTH                        18467535.82              0.152963
# 4   BEDOK RESERVOIR                        10059646.80              0.170511
# ..              ...                                ...                   ...
# 70    WATERWAY EAST                        18087011.88              0.148130
# 71   WOODLANDS EAST                        18592628.33              0.167987
# 72   WOODLANDS WEST                        11593616.68              0.156989
# 73          YEW TEE                         9949096.78              0.166572
# 74      YISHUN WEST                        11387775.46              0.162099
#
#          00 - 19       20 - 39       40 - 59     60 & Over  Average Income
# 0    5122.252793  10458.081465  11223.163288  12593.503017    13975.923484
# 1    4067.156260   5603.213452   5317.299340   7042.132011    19689.614782
# 2   17236.756103  14465.103663  19500.791783  11801.692781    10323.206492
# 3   10976.204112  18958.853121  22056.100938  27943.153446     8936.342609
# 4    4860.626994   7077.883636   7833.619187   6448.624985    12714.717735
# ..           ...           ...           ...           ...             ...
# 70  20729.174355  19196.080855  32524.779177   7367.837088    10233.068491
# 71  21820.835205  29345.543639  32416.392273  23409.661388     9628.062327
# 72   6106.183179   9709.618690   9311.253662  10994.809353     7373.988048
# 73   4707.983975  10597.570993  11633.502435  10049.571598    11200.734758
# 74   5586.482555  11041.790833  15295.013378  16387.116590     9103.165953
#
# [75 rows x 8 columns]

# %%
dT_predicted_subzone_data = dT_predicted_subzone_data.sort_values(by=['TAP_IN_TAP_OUT_VOLUME_WEEKLY_2025'],ascending=False)
dT_predicted_subzone_data
# Out:
#               SUBZONE_N  TAP_IN_TAP_OUT_VOLUME_WEEKLY_2025  \
# 28  JURONG WEST CENTRAL                        20742673.93
# 39              MATILDA                        19568701.83
# 62        TAMPINES WEST                        19490441.98
# 51        PUNGGOL FIELD                        19329322.12
# 21             FERNVALE                        18793935.36
# ..                  ...                                ...
# 59          SUNGEI ROAD                         2499285.05
# 44       NATURE RESERVE                         2416614.50
# 18           DAIRY FARM                         2160742.53
# 49                 PORT                         1629891.23
# 67            TURF CLUB                         1554528.56
#
#     Peak Hour Percentage       00 - 19       20 - 39       40 - 59  \
# 28              0.177487   8753.205425  13430.176428  21294.620525
# 39              0.152429  18149.352411  18905.659524  28547.467977
# 62              0.166681  15265.233780  23922.926214  20913.442726
# 51              0.153721  13138.094320  11882.928124  21044.738536
# 21              0.144997  21789.944591  19692.454212  40199.396285
# ..                   ...           ...           ...           ...
# 59              0.157634    224.791111    372.852386    484.810787
# 44              0.170939    776.607629    986.320320   1320.392837
# 18              0.165606   1931.636522   2024.680443   3427.507078
# 49              0.225999     12.325169     42.149911      8.991005
# 67              0.225460    113.428734    177.073967    190.000000
#
#        60 & Over  Average Income
# 28  13943.247113    10063.266144
# 39   8197.378796    10331.212938
# 62  23779.495070    10328.011754
# 51  10669.777821    11477.691768
# 21  11981.567527    12016.899186
# ..           ...             ...
# 59    678.620717     4669.573964
# 44   1066.649709    21330.577826
# 18   1520.552240    21890.934142
# 49     27.758108    25942.959311
# 67    189.267119    26058.000000
#
# [75 rows x 8 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sb.barplot(ax=ax, x="TAP_IN_TAP_OUT_VOLUME_WEEKLY_2025", y="SUBZONE_N", data=dT_predicted_subzone_data)
# Out:
# <AxesSubplot:xlabel='TAP_IN_TAP_OUT_VOLUME_WEEKLY_2025', ylabel='SUBZONE_N'>

# %%
dT_predicted_subzone_data_top20 = dT_predicted_subzone_data.head(20)
dT_predicted_subzone_data_top20
# Out:
#                SUBZONE_N  TAP_IN_TAP_OUT_VOLUME_WEEKLY_2025  \
# 28   JURONG WEST CENTRAL                        20742673.93
# 39               MATILDA                        19568701.83
# 62         TAMPINES WEST                        19490441.98
# 51         PUNGGOL FIELD                        19329322.12
# 21              FERNVALE                        18793935.36
# 71        WOODLANDS EAST                        18592628.33
# 3            BEDOK NORTH                        18467535.82
# 70         WATERWAY EAST                        18087011.88
# 61         TAMPINES EAST                        17177849.04
# 57  SENGKANG TOWN CENTRE                        16011161.65
# 52   PUNGGOL TOWN CENTRE                        13497002.26
# 72        WOODLANDS WEST                        11593616.68
# 74           YISHUN WEST                        11387775.46
# 7              BENDEMEER                        11250485.50
# 55     SEMBAWANG CENTRAL                        11171610.98
# 60          TAMAN JURONG                        11076405.56
# 10   BUKIT BATOK CENTRAL                        11045772.48
# 54             RIVERVALE                        10639150.73
# 31             KEMBANGAN                        10606864.06
# 13        CLEMENTI NORTH                        10238669.61
#
#     Peak Hour Percentage       00 - 19       20 - 39       40 - 59  \
# 28              0.177487   8753.205425  13430.176428  21294.620525
# 39              0.152429  18149.352411  18905.659524  28547.467977
# 62              0.166681  15265.233780  23922.926214  20913.442726
# 51              0.153721  13138.094320  11882.928124  21044.738536
# 21              0.144997  21789.944591  19692.454212  40199.396285
# 71              0.167987  21820.835205  29345.543639  32416.392273
# 3               0.152963  10976.204112  18958.853121  22056.100938
# 70              0.148130  20729.174355  19196.080855  32524.779177
# 61              0.156774  18670.117650  26002.917486  31163.876237
# 57              0.151395  14423.147011  18401.754861  19446.786278
# 52              0.147408  16173.705398  12103.535766  22322.664862
# 72              0.156989   6106.183179   9709.618690   9311.253662
# 74              0.162099   5586.482555  11041.790833  15295.013378
# 7               0.171481   6775.427604  10041.168824  10735.457927
# 55              0.171766   7635.103887   9526.150363  12649.322016
# 60              0.175812   8816.201719  11622.820824  13650.170653
# 10              0.177267   5269.340598   7630.445816   7192.788203
# 54              0.154771   5378.049857  16989.257962  17191.407816
# 31              0.177040   5281.953009   7773.224924   8544.200591
# 13              0.179821   4874.928423   7681.400301   7854.702713
#
#        60 & Over  Average Income
# 28  13943.247113    10063.266144
# 39   8197.378796    10331.212938
# 62  23779.495070    10328.011754
# 51  10669.777821    11477.691768
# 21  11981.567527    12016.899186
# 71  23409.661388     9628.062327
# 3   27943.153446     8936.342609
# 70   7367.837088    10233.068491
# 61  40363.341314     8937.417560
# 57  15814.600416    10493.815845
# 52   4768.402312     9151.312102
# 72  10994.809353     7373.988048
# 74  16387.116590     9103.165953
# 7   14637.478286     9587.868321
# 55   9268.184419    10585.022474
# 60   9631.663519    10488.617350
# 10   7979.517209     8880.004625
# 54  14652.377632    10915.178423
# 31  13504.723103    13114.997123
# 13   8477.670786     7518.110051

# %%
fig, ax = plt.subplots(figsize=(20, 20))
graph = sb.barplot(ax=ax, x="TAP_IN_TAP_OUT_VOLUME_WEEKLY_2025", y="SUBZONE_N", data=dT_predicted_subzone_data_top20)

# %%
listOfTop20Subzones = []
for i in range(20):
    listOfTop20Subzones.append(dT_predicted_subzone_data.iloc[i]['SUBZONE_N'])
listOfTop20Subzones
# Out:
# ['JURONG WEST CENTRAL',
#  'MATILDA',
#  'TAMPINES WEST',
#  'PUNGGOL FIELD',
#  'FERNVALE',
#  'WOODLANDS EAST',
#  'BEDOK NORTH',
#  'WATERWAY EAST',
#  'TAMPINES EAST',
#  'SENGKANG TOWN CENTRE',
#  'PUNGGOL TOWN CENTRE',
#  'WOODLANDS WEST',
#  'YISHUN WEST',
#  'BENDEMEER',
#  'SEMBAWANG CENTRAL',
#  'TAMAN JURONG',
#  'BUKIT BATOK CENTRAL',
#  'RIVERVALE',
#  'KEMBANGAN',
#  'CLEMENTI NORTH']
